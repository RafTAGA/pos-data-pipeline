# %%
from google.colab import drive, userdata
drive.mount('/content/drive')
import os
import sys
sys.path.append('/content/drive/...../modules')
import api_marginedge as marginedge # type: ignore
import json_processing_purchaise_orders as me_processing # type: ignore

# %% [markdown]
# ## Enter API related variables for calls
#
# Set these before running the cell below. They come from your own MarginEdge
# account and Colab setup, not from this repo:
#
# | Variable | Where to find it |
# |---|---|
# | `MARGINEDGE_API_KEY` | MarginEdge API key for your account (MarginEdge -> Settings -> Integrations -> API) |
# | `RESTAURANT_UNIT_ID` | MarginEdge `restaurantUnitId` for the specific location being pulled |
#
# In Google Colab: **Runtime -> Secrets** (key icon, left sidebar) -> add each
# value under the exact name shown above -> grant this notebook access when
# prompted. `userdata.get(...)` reads them from there. Never hardcode real
# credentials directly into a cell.

# %%
print("Getting Toast API Client ID:")
api_key = userdata.get('MARGINEDGE_API_KEY').strip()

print("Getting Toast API Client Secret:")
restaurant_unit_id = userdata.get('RESTAURANT_UNIT_ID').strip()

# %%
start_year_month = (2023, 5)
end_year_month = (2023, 12)
start_year = int(start_year_month[0])
start_month = int(start_year_month[1])
end_year = int(end_year_month[0])
end_month = int(end_year_month[1])
json_output_dir = "/content/drive/...../raw_purchaise_orders/" + str(start_year)
os.makedirs(os.path.dirname(json_output_dir), exist_ok=True)

print(f"Running Margin Edge Purchaise Order Extraction: {start_year_month} -> {end_year_month}")
print(f"Output dir: {json_output_dir}")

marginedge.run_marginedge_extraction(
                                      api_key=api_key,
                                      restaurant_unit_id=restaurant_unit_id,
                                      start_year_month=start_year_month,
                                      end_year_month=end_year_month,
                                      output_dir=json_output_dir,
                                     )

# %%
start_year_month = (2024, 1)
end_year_month = (2024, 12)
start_year = int(start_year_month[0])
start_month = int(start_year_month[1])
end_year = int(end_year_month[0])
end_month = int(end_year_month[1])
json_output_dir = "/content/drive/...../raw_purchaise_orders/" + str(start_year)
os.makedirs(os.path.dirname(json_output_dir), exist_ok=True)

print(f"Running Margin Edge Purchaise Order Extraction: {start_year_month} -> {end_year_month}")
print(f"Output dir: {json_output_dir}")

marginedge.run_marginedge_extraction(
                                      api_key=api_key,
                                      restaurant_unit_id=restaurant_unit_id,
                                      start_year_month=start_year_month,
                                      end_year_month=end_year_month,
                                      output_dir=json_output_dir,
                                     )

# %%
start_year_month = (2025, 1)
end_year_month = (2025, 12)
start_year = int(start_year_month[0])
start_month = int(start_year_month[1])
end_year = int(end_year_month[0])
end_month = int(end_year_month[1])
json_output_dir = "/content/drive/...../raw_purchaise_orders/" + str(start_year)
os.makedirs(os.path.dirname(json_output_dir), exist_ok=True)

print(f"Running Margin Edge Purchaise Order Extraction: {start_year_month} -> {end_year_month}")
print(f"Output dir: {json_output_dir}")

marginedge.run_marginedge_extraction(
                                      api_key=api_key,
                                      restaurant_unit_id=restaurant_unit_id,
                                      start_year_month=start_year_month,
                                      end_year_month=end_year_month,
                                      output_dir=json_output_dir,
                                     )

# %%
start_year_month = (2026, 1)
end_year_month = (2026, 6)
start_year = int(start_year_month[0])
start_month = int(start_year_month[1])
end_year = int(end_year_month[0])
end_month = int(end_year_month[1])
json_output_dir = "/content/drive/...../raw_purchaise_orders/" + str(start_year)
os.makedirs(os.path.dirname(json_output_dir), exist_ok=True)

print(f"Running Margin Edge Purchaise Order Extraction: {start_year_month} -> {end_year_month}")
print(f"Output dir: {json_output_dir}")

marginedge.run_marginedge_extraction(
                                      api_key=api_key,
                                      restaurant_unit_id=restaurant_unit_id,
                                      start_year_month=start_year_month,
                                      end_year_month=end_year_month,
                                      output_dir=json_output_dir,
                                     )

# %%
base = "/content/drive/...../raw_purchaise_orders"
year_dirs_raw = ",".join(f"{base}/{y}" for y in [2023, 2024, 2025, 2026])
year_order_dirs = [p.strip() for p in year_dirs_raw.split(",") if p.strip()]


for dir in year_order_dirs:
  if not os.path.isdir(dir):
    print(f"ERROR: '{dir}' is not a directory (check ORDERS_YEAR_DIRS / START_YEAR).", file=sys.stderr)
    sys.exit(1)

purchaise_orders_csv_output_path = base + "/marginedge_purchaise_orders.csv"
os.makedirs(os.path.dirname(purchaise_orders_csv_output_path), exist_ok=True)

line_items_csv_path = base + "/marginedge_line_items.csv"
os.makedirs(os.path.dirname(purchaise_orders_csv_output_path), exist_ok=True)

print(f"Processing year dirs: {year_order_dirs}")
print(f"CSV output: {purchaise_orders_csv_output_path}")
me_processing.build_marginedge_dataframes(marginedge_dirs=year_order_dirs,
                                          orders_output_path=purchaise_orders_csv_output_path,
                                          line_items_output_path=line_items_csv_path,
                                          )
